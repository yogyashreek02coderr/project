# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "5AI.csv" # Replace with your dataset file path
df = pd.read_csv(file_path)
print(df)
# Out:
#                      Name         USN  Internal  External  Total
# 0   ADITHYA ASHOK SAPALYA  4VP22AI001        30        22     52
# 1                ADYA N L  4VP22AI002        39        32     71
# 2              AISHWARYA   4VP22AI003        40        30     70
# 3        AKHILA KARUVAJE   4VP22AI004        47        42     89
# 4            AKSHAY KUMAR  4VP22AI005        41        38     79
# ..                    ...         ...       ...       ...    ...
# 56           THISHUKUMAR   4VP22AI057        39        30     69
# 57           THRISHA RAI   4VP22AI058        46        31     77
# 58               THRUPTHI  4VP22AI059        42        28     70
# 59             UTTAM RAI   4VP22AI060        41        39     80
# 60           YOGYASHREE K  4VP22AI061        41        30     71
#
# [61 rows x 5 columns]

# %%
column1 = "Internal" # Replace with the first column name
column2 = "External" # Replace with the second column name
selected_data = df[[column1, column2]]

# %%
plt.figure(figsize=(8, 6))
plt.scatter(selected_data[column1], selected_data[column2], color="blue", alpha=0.7)
plt.title(f"Scatter Plot of {column1} vs {column2}")
plt.xlabel(column1)
plt.ylabel(column2)
plt.grid(True)
plt.show()

# %%
correlation_coefficient = np.corrcoef(selected_data[column1],selected_data[column2])[0, 1]
print(f"Pearson Correlation Coefficient ({column1} vs {column2}):{correlation_coefficient}")
# Out:
# Pearson Correlation Coefficient (Internal vs External):0.3237960800593649

# %%
cov_matrix = np.cov(selected_data[column1], selected_data[column2])
print("\nCovariance Matrix:")
print(cov_matrix)
# Out:
# Covariance Matrix:
# [[14.12404372  7.13497268]
#  [ 7.13497268 34.37814208]]

# %%
correlation_matrix = selected_data.corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#           Internal  External
# Internal  1.000000  0.323796
# External  0.323796  1.000000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f",
cbar=True)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
col3="Total"
col4="Internal"
selected_data=df[[col3,col4]]

# %%
plt.figure(figsize=(8,5))
plt.scatter(selected_data[col3],selected_data[col4],color='blue',alpha=0.8)
plt.title(f' scatter plot of {col3} vs {col4}')
plt.xlabel(col3)
plt.ylabel(col4)
plt.grid(True)
plt.show()

# %%
cor_coef=np.corrcoef(selected_data[col3],selected_data[col4])[0,1]
print(f'pearson correlation coefficient ({col3} vs {col4}): {cor_coef}')
# Out:
# pearson correlation coefficient (Total vs Internal): 0.7139703942936728

# %%
cova_matrix = np.cov(selected_data[col3], selected_data[col4])
print("\nCovariance Matrix:")
print(cova_matrix)
# Out:
# Covariance Matrix:
# [[62.77213115 21.25901639]
#  [21.25901639 14.12404372]]

# %%
correlation_matrix = selected_data.corr()
print("\ncorrelation matrix:")
print(correlation_matrix)
# Out:
# correlation matrix:
#             Total  Internal
# Total     1.00000   0.71397
# Internal  0.71397   1.00000

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f",
cbar=True)
plt.title("Correlation Matrix Heatmap")
plt.show()
